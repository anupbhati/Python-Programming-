# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### first program

# %%
print("hello world")
# Out:
# hello world
