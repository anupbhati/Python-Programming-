# %%
x = int(input("sam::enter your age:"))
# Out:
# sam::enter your age: 25

# %%
x
# Out:
# 25

# %%
y=x+30

# %%
y
# Out:
# 55

# %%
print("sam is ",x," years old  and his father is ",y," old.")
# Out:
# sam is  25  years old  and his father is  55  old.

# %%
print("sam is {a} years old and his father is {b} old.".format(a=x, b=y))
# Out:
# sam is 25 years old and his father is 55 old.

# %%
print("sam is {0} years old and his father is {1} old".format(x,y))
# Out:
# sam is 25 years old and his father is 55 old

# %%
print("sam is {} years old and his father is {} old".format(x,y))
# Out:
# sam is 25 years old and his father is 55 old
