# %%
var=2

# %%
_var=3

# %%
_1var=9

# %%
var_=4

# %% [markdown]
# # arithmetic operations

# %%
x=2
y=3

# %%
#addition

# %%
x+y
# Out:
# 5

# %%
#subtraction

# %%
x-y
# Out:
# -1

# %%
#multiplication

# %%
x*y
# Out:
# 6

# %%
#division

# %%
x/y
# Out:
# 0.6666666666666666

# %%
#exponentation

# %%
x**y
# Out:
# 8

# %%
pow(x,y)
# Out:
# 8

# %%
#quotient

# %%
x//y
# Out:
# 0

# %%
#modulus

# %%
x%y
# Out:
# 2
