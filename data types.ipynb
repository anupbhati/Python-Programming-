# %%
x= 10

# %%
type(x)
# Out:
# int

# %%
x='10'

# %%
type(x)
# Out:
# str

# %%
x='10'

# %%
type(x)
# Out:
# str

# %%
x=10.5

# %%
type(x)
# Out:
# float

# %%
x= True

# %%
type(x)
# Out:
# bool

# %%
X= False

# %%
type(x)
# Out:
# bool

# %%
x= 3+2j

# %%
type(x)
# Out:
# complex

# %%
x=[1,2,3, 'Hello']

# %%
type(x)
# Out:
# list

# %%
x=(1,2,3,"Hello")

# %%
type(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 type(x)
#
# NameError: name 'x' is not defined

# %%
x=(1,2,3,'hello')

# %%
type(x)
# Out:
# tuple

# %%
x=(1,2,3,'Hello')

# %%
x=(1,2,3,'hello')

# %%
type(x)
# Out:
# tuple

# %%
type(x)
# Out:
# tuple

# %%
x={1,2,3,'Hello'}

# %%
type(x)
# Out:
# set

# %%
x={1,2,3,'hello'}

# %%
type(x)
# Out:
# set

# %%
x={'black':11,'red':12,'green':13}

# %%
type(x)
# Out:
# dict
