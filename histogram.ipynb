# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
marks=np.random.randint(0,100,(50))

# %%
print(marks)
# Out:
# [66 86 70 57 18 95 56 23 72 35 52 17 78  1 90 54 64 73 76 81 48 54 64  3
#  21 96 66 19 99 25 79 43 22 30 77 65 72 19 34 77 83 28 25 55 79 93 92 69
#   2  8]

# %%
plt.hist(marks)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df=pd.read_csv(r"C:\Users\msi-1\Downloads\tip.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df[['tip','sex']].hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,8))
plt.ylabel('Tips')
plt.hist(df['tip'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
