# %%
print("this is my first program")
# Out:
# this is my first program

# %%
#my name is anup

# %%
#if you want to comment in 
#multiple lines just select all text and  click on control

# %%
#if you want to comment 
#in multiple lines just select all text and click on control
