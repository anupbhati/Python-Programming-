# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %%
# FIRST PROGRAM

# %% [markdown]
# ## SECOND PROGRAM

# %% [markdown]
# ### THIRD PROGRAM

# %% [markdown]
# #### USING MARKDOWN

# %% [markdown]
# ##### MARKDOWN

# %%
print(25*35)
# Out:
# 875

# %% [markdown]
# # first program

# %% [markdown]
# ## second program

# %% [markdown]
# ###### third program

# %% [markdown]
# ###### fourth program

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# # first program

# %% [markdown]
# #### second program
