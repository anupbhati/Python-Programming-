# %% [markdown]
# # first program

# %% [markdown]
# #### second program

# %%
print('thuis is my first program')
# Out:
# thuis is my first program

# %% [markdown]
# # thus

# %%
print('this is my second program')
# Out:
# this is my second program

# %%
# thus is my third program
#this is my fifth program
# this is my sisth program

# %% [markdown]
# # arithmetic operations

# %% [markdown]
# ## addition

# %%
2*4
# Out:
# 8

# %%
99*99
# Out:
# 9801

# %% [markdown]
# ## subtraction

# %%
34-0
# Out:
# 34

# %%
56-98
# Out:
# -42

# %% [markdown]
# ## multiplication

# %%
33*67
# Out:
# 2211

# %%
23*76
# Out:
# 1748

# %% [markdown]
# ## EXPONENTATION

# %%
2**3
# Out:
# 8

# %%
pow(4,3)
# Out:
# 64

# %% [markdown]
# ## division

# %%
33/11
# Out:
# 3.0

# %%
44/3
# Out:
# 14.666666666666666

# %% [markdown]
# ## quotient

# %%
23//1
# Out:
# 23

# %%
56//4
# Out:
# 14

# %% [markdown]
# ## MODULUS

# %%
4%2
# Out:
# 0

# %%
44%3
# Out:
# 2

# %% [markdown]
# # VARIABLES

# %%
VAR1= 4

# %%
VAR1
# Out:
# 4

# %%
_VAR1=45

# %%
_VAR1
# Out:
# 45

# %%
VAR$=67
# Out:
#   Cell In[25], line 1
#     VAR$=67
#        ^
# SyntaxError: invalid syntax

# %%
_3var=77

# %%
_3var
# Out:
# 77

# %% [markdown]
# # ARTHIMETIC OPERATIONS  ON VARIABLES

# %%
x=2
y=3

# %%
# addition

# %%
x+y
# Out:
# 5

# %%
# subtraction

# %%
x-y
# Out:
# -1

# %%
# multiplication

# %%
x*y
# Out:
# 6

# %%
# division

# %%
x/y
# Out:
# 0.6666666666666666

# %%
# exponentation

# %%
x**y
# Out:
# 8

# %%
pow(x,y)
# Out:
# 8

# %%
# quotient

# %%
x//y
# Out:
# 0

# %%
# modulus or reminder

# %%
x%y
# Out:
# 2

# %% [markdown]
# # BASIC DATA TYPES IN PYTHON

# %%
x=10
type(x)
# Out:
# int

# %%
x='10'
type(x)
# Out:
# str

# %%
x=10.25
type(x)
# Out:
# float

# %%
x= True
type(x)
# Out:
# bool

# %%
x = False
type(x)
# Out:
# bool

# %%
x= 3+2j
type(x)
# Out:
# complex

# %%
x=[1,2,3,'hello']

# %%
type(x)
# Out:
# list

# %%
x=(1,2,3,'hello')
type(x)
# Out:
# tuple

# %%
x={1,2,3,'hello'}
type(x)
# Out:
# set

# %%
x={'black':12,'green':13,'red':14}
type(x)
# Out:
# dict

# %% [markdown]
# # TYPE CASTING IN PYTHON

# %% [markdown]
# ## INT TO FLOAT TO STRING

# %%
#string to integer

# %%
x='12'
type(x)
# Out:
# str

# %%
int(x)
# Out:
# 12

# %%
int('12')
# Out:
# 12

# %%
# float to string

# %%
int(13.45)
# Out:
# 13

# %%
int(1.99)
# Out:
# 1

# %%
# string to float

# %%
float('12')
# Out:
# 12.0

# %%
float("12.99")
# Out:
# 12.99

# %%
#string to float to int

# %%
int(float('12.99'))
# Out:
# 12

# %% [markdown]
# # USER INPUT

# %%
input()
# Out:
#  10
# '10'

# %%
input('enter your age:')
# Out:
# enter your age 24
# '24'

# %%
input('enter your age:')
# Out:
# enter your age: 10
# '10'

# %%
x=input('enter your age')
# Out:
# enter your age 10

# %%
x=input('enter your age:')
# Out:
# enter your age: 10

# %%
x
# Out:
# '10'

# %%
x=int(input('enter your age'))
# Out:
# enter your age 10

# %%
x
# Out:
# 10

# %%
x=float(input('enter your age'))
# Out:
# enter your age 10

# %%
x
# Out:
# 10.0

# %%
x=int(input('enter your age'))
# Out:
# enter your age 25

# %%
print(x)
# Out:
# 25

# %%
print('my age is ',x)
# Out:
# my age is  25

# %% [markdown]
# # fromating print statement

# %%
x= int(input("Sam::enter your age:"))
# Out:
# Sam::enter your age: 25

# %%
x
# Out:
# 25

# %%
y= x+25

# %%
y
# Out:
# 55

# %% [markdown]
# # four ways of formatting print statement in pyhton

# %%
print("sam is ",x," years old and his father is , ",y," years old ")
# Out:
# sam is  30  years old and his father is ,  55  years old

# %%
print("sam is {a} years old and hi father is {b} years old.". format(a=x,b=y))
# Out:
# sam is 30 years old and hi father is 55 years old.

# %%
print("sam is {0} years ols and his father is {1} years old .".format(x,y))
# Out:
# sam is 30 years ols and his father is 55 years old .

# %%
print("sam is {} years old and his father is {} years old".format(x,y))
# Out:
# sam is 30 years old and his father is 55 years old

# %%
# indentation

# %%
x=1
if (x>=1):
    print("correct")
# Out:
# correct

# %%
for i in range(0,5):
    if (i>3):
        print(i)
# Out:
# 4

# %%
# assign operators

# %%
x
# Out:
# 5

# %%
x=x+10

# %%
x
# Out:
# 15

# %%
x+=10

# %%
x
# Out:
# 25

# %%
x=x-10

# %%
x
# Out:
# 15

# %%
x-=10

# %%
x
# Out:
# -20

# %%
x=x

# %% [markdown]
# # if and else statement

# %%
x=9
x
# Out:
# 9

# %%
if (x>5):
    print("x is greater than 5")
# Out:
# x is greater than 5

# %%
if (x==10):
    print("x is equal to 10")
# Out:
# x is equal to 10

# %%
if (x>15):
    print("x is greater than 15")
else:
    print("x is lesser than 15")
# Out:
# x is lesser than 15

# %%
if (x<=5):
    print("x is lesser than equal to 5")
elif(x>5) and (x<10):
    print("x is between 5 and 10")
else:
    print("x is greater than equal to 10")
# Out:
# x is between 5 and 10

# %%
if(x<=5):
    print("x is lesser tha equal to 5")
elif ((x>5)&(x<15)):
    print("x is between 5 and 15")
else:
    print("x is greater than equal to 15")
# Out:
# x is between 5 and 15

# %%
# if no is divided by 2 it is even
# if no is divided by 5 or 7 it can be divided 
# if no is not divided by 2 or 5 or 7 we will say it cannot be divided

# %%
if(x%2==0):
    print("x is even")
elif((x%5==0) or (x%7==0)):
    print("x can be divided ")
else:
    print(" x cannot be divided")
# Out:
# x can be divided

# %%
x=5

# %% [markdown]
# # list

# %%
list1=[1,2,3,4,5]

# %%
print(list1)
# Out:
# [1, 2, 3, 4, 5]

# %%
# list indexing

# %%
list1[0]
# Out:
# 1

# %%
list1[3]
# Out:
# 4

# %%
# negative indexing

# %%
list1[-1]
# Out:
# 5

# %%
# list slicing

# %%
l1=[2,5,7,8,9,0]

# %%
l1[0:3]
# Out:
# [2, 5, 7]

# %%
l1[:]
# Out:
# [2, 5, 7, 8, 9, 0]

# %%
# skipping element while slicing using [::]

# %%
l1[1::4]
# Out:
# [5, 0]

# %%
l1[-1::-4]
# Out:
# [0, 5]

# %%
l1[0:6:2]
# Out:
# [2, 7, 9]

# %%
l1[::-1]
# Out:
# [0, 9, 8, 7, 5, 2]

# %%
l1[1::2]
# Out:
# [5, 8, 0]

# %%
l1[1::2]
# Out:
# [5, 8, 0]

# %%
# list methods

# %%
A=[1,2,2,2,3,3,1,4,6,7,8,8,7,7,9,9,9,0,0]

# %%
A
# Out:
# [1, 2, 2, 2, 3, 3, 1, 4, 6, 7, 8, 8, 7, 7, 9, 9, 9, 0, 0, 10]

# %%
A.append(10)

# %%
A
# Out:
# [1, 2, 2, 2, 3, 3, 1, 4, 6, 7, 8, 8, 7, 7, 9, 9, 9, 0, 0, 10]

# %%
A
# Out:
# [1, 2, 2, 2, 3, 3, 1, 4, 6, 7, 8, 8, 7, 7, 9, 9, 9, 0, 0, 10]

# %%
A
# Out:
# [1, 2, 2, 2, 3, 3, 1, 4, 6, 7, 8, 8, 7, 7, 9, 9, 9, 0, 0, 10]

# %%
A
# Out:
# [1, 2, 2, 2, 3, 3, 1, 4, 6, 7, 8, 8, 7, 7, 9, 9, 9, 0, 0]

# %%
A.extend([10,20])

# %%
A
# Out:
# [1, 2, 2, 2, 3, 3, 1, 4, 6, 7, 8, 8, 7, 7, 9, 9, 9, 0, 0, 10, 20]

# %%
A.append([10,20])

# %%
A
# Out:
# [1, 2, 2, 2, 3, 3, 1, 4, 6, 7, 8, 8, 7, 7, 9, 9, 9, 0, 0, 10, 20, [10, 20]]

# %%
A
# Out:
# [1, 2, 2, 2, 3, 3, 1, 4, 6, 7, 8, 8, 7, 7, 9, 9, 9, 0, 0]

# %%
A.insert(2,24)

# %%
A
# Out:
# [1, 2, 24, 2, 2, 3, 3, 1, 4, 6, 7, 8, 8, 7, 7, 9, 9, 9, 0, 0]

# %%
A
# Out:
# [1, 2, 2, 2, 3, 3, 1, 4, 6, 7, 8, 8, 7, 7, 9, 9, 9, 0, 0]

# %%
A.pop()
# Out:
# 0

# %%
A
# Out:
# [1, 2, 2, 2, 3, 3, 1, 4, 6, 7, 8, 8, 7, 7, 9, 9, 9, 0]

# %%
A.pop(3)
# Out:
# 2

# %%
A
# Out:
# [1, 2, 2, 3, 3, 1, 4, 6, 7, 8, 8, 7, 7, 9, 9, 9, 0, 0]

# %%
A
# Out:
# [1, 2, 2, 3, 3, 1, 4, 6, 7, 8, 8, 7, 7, 9, 9, 9, 0, 0]

# %%
A.remove(2)

# %%
A
# Out:
# [1, 2, 2, 3, 3, 1, 4, 6, 7, 8, 8, 7, 7, 9, 9, 9, 0, 0]

# %%
A.count(9)
# Out:
# 3

# %%
A.count(5)
# Out:
# 0

# %%
A
# Out:
# [1, 2, 2, 3, 3, 1, 4, 6, 7, 8, 8, 7, 7, 9, 9, 9, 0, 0]

# %%
A.index(3)
# Out:
# 3

# %%
A
# Out:
# [1, 2, 2, 3, 3, 1, 4, 6, 7, 8, 8, 7, 7, 9, 9, 9, 0, 0]

# %%
A.sort()

# %%
A
# Out:
# [0, 0, 1, 1, 2, 2, 3, 3, 4, 6, 7, 7, 7, 8, 8, 9, 9, 9]

# %%
A.sort(reverse=True)

# %%
A
# Out:
# [9, 9, 9, 8, 8, 7, 7, 7, 6, 4, 3, 3, 2, 2, 1, 1, 0, 0]

# %%
len(A)
# Out:
# 18

# %%
# STRING METHODS

# %%
A=" HELLO WORLD "

# %%
A.strip()
# Out:
# 'HELLO WORLD'

# %%
A.lower()
# Out:
# 'hello world'

# %%
A.upper()
# Out:
# 'HELLO WORLD'

# %%
A.replace('HELLO','NEW')
# Out:
# 'NEW WORLD'

# %%
A.split(",")
# Out:
# ['HELLO WORLD']

# %% [markdown]
# # factorial of a number

# %%
# 5!=5*4*3*2*1

# %%
x=1
for i in range(1,6):
    x=x*i
    print(x)
# Out:
# 1
# 2
# 6
# 24
# 120

# %%
x=1
for i in range(1,6):
    x=x*i
print(x)
# Out:
# 120

# %%
x=10
for i in range (0,5):
    x=x-1
    print(x)
# Out:
# 9
# 8
# 7
# 6
# 5

# %%
y=int(input("enter your number"))
x=1
for i in range(1,y+1):
    x=x*i
    print(x)
# Out:
# enter your number 5
# 1
# 2
# 6
# 24
# 120
